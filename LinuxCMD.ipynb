# %% [markdown]
# <a href="https://colab.research.google.com/github/hoooooola/jeson-nano/blob/day1/LinuxCMD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %%
ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Dec  9 14:35 ./
# drwxr-xr-x 1 root root 4096 Dec 20 06:25 ../
# drwxr-xr-x 4 root root 4096 Dec  9 14:35 .config/
# drwxr-xr-x 1 root root 4096 Dec  9 14:35 sample_data/

# %% [markdown]
# 權限, 使用次數, 建立者, 群組, 大小, 建立時間, 文件名稱
#
# drwxr-xr-x
#
# d : 文件夾
#
# rwx:(超級管理者的權限) read 讀, write寫, execute 執行, - 不能使用
#
# r-x:(有帳戶密碼登入的使用者的權限)
#
# r-x:(沒有帳戶密碼登入的使用者的權限, 一般使用者)

# %%
ls -a
# Out:
# ./  ../  .config/  sample_data/

# %%
ls /
# Out:
# bin@      dev/     lib@     media/  python-apt/         sbin@  tools/
# boot/     etc/     lib32@   mnt/    python-apt.tar.xz*  srv/   usr/
# content/  home/    lib64@   opt/    root/               sys/   var/
# datalab/  kaggle/  libx32@  proc/   run/                tmp/

# %%
ls ~

# %%
cd ~
# Out:
# /root

# %%
cd ..
# Out:
# /

# %%
pwd
# Out:
# '/'

# %%
ls
# Out:
# bin@      dev/     lib@     media/  python-apt/         sbin@  tools/
# boot/     etc/     lib32@   mnt/    python-apt.tar.xz*  srv/   usr/
# content/  home/    lib64@   opt/    root/               sys/   var/
# datalab/  kaggle/  libx32@  proc/   run/                tmp/

# %%
cd content/
# Out:
# /content

# %%
ls
# Out:
# sample_data/

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from os import mkdir
get_ipython().system('mkdir hola')

# %%
# !mkdir hoola

# %%
ls
# Out:
# anscombe.json*                hola/           mnist_train_small.csv
# california_housing_test.csv   hoola/          README.md*
# california_housing_train.csv  mnist_test.csv

# %%
cd ..
# Out:
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
# 'Google AI Studio'/              未命名的試算表.gsheet
#  伺服器端飛行數據分析策略.gdoc   無人機黑盒子AI分析建議.gdoc
# '未命名文件 (1).gdoc'            記帳home.gsheet
#  未命名文件.gdoc                 飛行日誌AI分析策略優化.gdoc

# %%
cp 無人機黑盒子AI分析建議.gdoc 1.gdoc
# Out:
# cp: cannot open '無人機黑盒子AI分析建議.gdoc' for reading: Operation not supported

# %%
# !nano 1.txt
# Out:
# /bin/bash: line 1: nano: command not found

# %%
ls
# Out:
# 'Google AI Studio'/              未命名的試算表.gsheet
#  伺服器端飛行數據分析策略.gdoc   無人機黑盒子AI分析建議.gdoc
# '未命名文件 (1).gdoc'            記帳home.gsheet
#  未命名文件.gdoc                 飛行日誌AI分析策略優化.gdoc

# %%
cp -rf
# Out:
# cp: missing file operand
# Try 'cp --help' for more information.

# %%
cp 1.txt 2.txt

# %%
rm 2.txt

# %%
cp -rf 1/
# Out:
# cp: missing destination file operand after '1/'
# Try 'cp --help' for more information.

# %%
ls
# Out:
#  1/                              未命名文件.gdoc
#  1.txt                           未命名的試算表.gsheet
# 'Google AI Studio'/              無人機黑盒子AI分析建議.gdoc
#  伺服器端飛行數據分析策略.gdoc   記帳home.gsheet
# '未命名文件 (1).gdoc'            飛行日誌AI分析策略優化.gdoc

# %%
mv 1.txt 2.txt

# %%
mv 2.txt 1

# %%
# !su
# Out:
# bash: cannot set terminal process group (729): Inappropriate ioctl for device
# bash: no job control in this shell
# /content/drive/MyDrive# cd ..
# /content/drive# exit
# exit

# %%
ls
# Out:
#  1/                              未命名文件.gdoc
#  2/                              未命名的試算表.gsheet
# 'Google AI Studio'/              無人機黑盒子AI分析建議.gdoc
#  伺服器端飛行數據分析策略.gdoc   記帳home.gsheet
# '未命名文件 (1).gdoc'            飛行日誌AI分析策略優化.gdoc

# %%
# !sudo find / -name 未*
# Out:
# find: paths must precede expression: `未命名文件.gdoc'
# find: possible unquoted pattern after predicate `-name'?

# %%
# !adduser adam
# Out:
# Adding user `adam' ...
# Adding new group `adam' (1000) ...
# Adding new user `adam' (1000) with group `adam' ...
# Creating home directory `/home/adam' ...
# Copying files from `/etc/skel' ...
# New password:
# Retype new password:
# passwd: password updated successfully
# Changing the user information for adam
# Enter the new value, or press ENTER for the default
# 	Full Name []: adam
# 	Room Number []: adam
# 	Work Phone []: adam
# 	Home Phone []: adam
# 	Other []: adam
# Is the information correct? [Y/n] y

# %%
#sudo halt #關機

# %%
#sudo reboot

# %%
# !ps #工作管理員
# Out:
#     PID TTY          TIME CMD
#       1 ?        00:00:00 docker-init
#       7 ?        00:00:04 node
#      20 ?        00:00:00 tail
#      21 ?        00:00:00 tail
#      33 ?        00:00:01 oom_monitor.sh
#      35 ?        00:00:00 run.sh
#      36 ?        00:00:01 kernel_manager_
#     146 ?        00:00:03 colab-fileshim.
#     171 ?        00:00:06 jupyter-server
#     172 ?        00:00:00 dap_multiplexer
#     729 ?        00:00:04 python3
#     772 ?        00:00:02 language_servic
#     780 ?        00:00:40 node
#    1112 ?        00:00:00 tmux: server
#   10840 ?        00:00:00 bash
#   10841 ?        00:00:00 drive
#   10842 ?        00:00:00 grep
#   10954 ?        00:00:01 drive
#   11031 ?        00:00:00 bash
#   11032 ?        00:00:00 directoryprefet
#   11033 ?        00:00:00 tail
#   11034 ?        00:00:00 python3
#   18498 ?        00:00:00 sleep
#   18499 ?        00:00:00 ps

# %%
# !ps aux
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root           1  0.0  0.0    984   572 ?        Ss   06:25   0:00 /sbin/docker-
# root           7  0.1  0.1 1308996 72036 ?       Sl   06:25   0:04 /tools/node/b
# root          20  0.0  0.0   5804  2152 ?        Ss   06:25   0:00 tail -n +0 -F
# root          21  0.0  0.0   5804  2212 ?        Ss   06:25   0:00 tail -n +0 -F
# root          33  0.0  0.0   7372  3480 ?        S    06:25   0:01 /bin/bash -e
# root          35  0.0  0.0   7372  1836 ?        S    06:25   0:00 /bin/bash -e
# root          36  0.0  0.0 1273940 19712 ?       Sl   06:25   0:01 /usr/colab/bi
# root         146  0.0  0.1  84956 72308 ?        S    06:25   0:03 python3 /usr/
# root         171  0.1  0.2 1262964 115192 ?      Sl   06:25   0:06 /usr/bin/pyth
# root         172  0.0  0.0 1230320 5656 ?        Sl   06:25   0:00 /usr/local/bi
# root         729  0.1  0.2 1655140 117784 ?      Ssl  06:27   0:04 /usr/bin/pyth
# ...

# %%
# !kill 19634 #關閉程式
# Out:
# /bin/bash: line 1: kill: (19634) - No such process

# %%
# !ifconfig #本機網路設定
# Out:
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 172.28.0.12  netmask 255.255.0.0  broadcast 172.28.255.255
#         ether 02:42:ac:1c:00:0c  txqueuelen 0  (Ethernet)
#         RX packets 17898  bytes 3484968 (3.4 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 13942  bytes 20155053 (20.1 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 25515  bytes 12208447 (12.2 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 25515  bytes 12208447 (12.2 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

# %%
/*
eth0 網路卡ip
wlan0 無限網路ip
lo localhost本機
/*

# %%
# !ping 8.8.8.8
# Out:
# /bin/bash: line 1: ping: command not found

# %%
# !wget data:image/jpeg;base64,...
# Out:
# --2025-12-20 07:51:14--  ftp://data/image/jpeg
#            => ‘jpeg’
# Resolving data (data)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘data’
# /bin/bash: line 1: base64,...: File name too long
